# %% [markdown]
# ### Filtering in Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv(r"E:\e1\Data science\Machine learning\inueron intern\insurance.csv")
raw_data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
raw_data[raw_data['region']=='southwest']
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 12     23    male  34.4         0     no  southwest   1826.84
# 15     19    male  24.6         1     no  southwest   1837.24
# 18     56    male  40.3         0     no  southwest  10602.39
# 19     30    male  35.3         0    yes  southwest  36837.47
# ...   ...     ...   ...       ...    ...        ...       ...
# 1316   19  female  20.6         0     no  southwest   1731.68
# 1329   52    male  38.6         2     no  southwest  10325.21
# 1331   23  female  33.4         0     no  southwest  10795.94
# 1332   52  female  44.7         3     no  southwest  11411.69
# 1336   21  female  25.8         0     no  southwest   2007.95
#
# [325 rows x 7 columns]

# %%
raw_data[raw_data['region'].isin(['southwest','northwest'])]
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# 7      37  female  27.7         3     no  northwest   7281.51
# 9      60  female  25.8         0     no  northwest  28923.14
# ...   ...     ...   ...       ...    ...        ...       ...
# 1331   23  female  33.4         0     no  southwest  10795.94
# 1332   52  female  44.7         3     no  southwest  11411.69
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [650 rows x 7 columns]

# %% [markdown]
# ### If you want to find the specific string

# %%
raw_data[raw_data['region'].str.contains('south')]
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 5      31  female  25.7         0     no  southeast   3756.62
# 6      46  female  33.4         1     no  southeast   8240.59
# ...   ...     ...   ...       ...    ...        ...       ...
# 1330   57  female  25.7         2     no  southeast  12629.17
# 1331   23  female  33.4         0     no  southwest  10795.94
# 1332   52  female  44.7         3     no  southwest  11411.69
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
#
# [689 rows x 7 columns]

# %% [markdown]
# ### To set any column as index

# %%
raw_data.set_index('age')
# Out:
#         sex   bmi  children smoker     region  expenses
# age
# 19   female  27.9         0    yes  southwest  16884.92
# 18     male  33.8         1     no  southeast   1725.55
# 28     male  33.0         3     no  southeast   4449.46
# 33     male  22.7         0     no  northwest  21984.47
# 32     male  28.9         0     no  northwest   3866.86
# ..      ...   ...       ...    ...        ...       ...
# 50     male  31.0         3     no  northwest  10600.55
# 18   female  31.9         0     no  northeast   2205.98
# 18   female  36.9         0     no  southeast   1629.83
# 21   female  25.8         0     no  southwest   2007.95
# 61   female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 6 columns]

# %% [markdown]
# ### If you want the specific columns from the data set
# when you set axis=0 it will look at rows
# axis = 1 look at columns

# %%
raw_data.filter(items=['smoker','region'],axis=1)
# Out:
#      smoker     region
# 0       yes  southwest
# 1        no  southeast
# 2        no  southeast
# 3        no  northwest
# 4        no  northwest
# ...     ...        ...
# 1333     no  northwest
# 1334     no  northeast
# 1335     no  southeast
# 1336     no  southwest
# 1337    yes  northwest
#
# [1338 rows x 2 columns]

# %%
raw_data.filter(items=['smoker','region'],axis=0)
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, expenses]
# Index: []

# %%
raw_data.filter(items=[19],axis=0)
# Out:
#     age   sex   bmi  children smoker     region  expenses
# 19   30  male  35.3         0    yes  southwest  36837.47

# %% [markdown]
# #### In order to Search the things with specific name

# %%
raw_data.filter(like='smoker',axis=1)
# Out:
#      smoker
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
# ...     ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
#
# [1338 rows x 1 columns]

# %% [markdown]
# #### Order by

# %%
raw_data[raw_data['age']<500].sort_values(by='age',ascending=True)
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1248   18  female  39.8         0     no  southeast   1633.96
# 482    18  female  31.4         0     no  southeast   1622.19
# 492    18  female  25.1         0     no  northeast   2196.47
# 525    18  female  33.9         0     no  southeast  11482.63
# 529    18    male  25.5         0     no  northeast   1708.00
# ...   ...     ...   ...       ...    ...        ...       ...
# 398    64    male  25.6         2     no  southwest  14988.43
# 335    64    male  34.5         0     no  southwest  13822.80
# 378    64  female  30.1         3     no  northwest  16455.71
# 1265   64    male  23.8         0    yes  southeast  26926.51
# 635    64    male  38.2         0     no  northeast  14410.93
#
# [1338 rows x 7 columns]

# %% [markdown]
# Descending Order

# %%
raw_data[raw_data['age']<500].sort_values(by=['age','smoker'],ascending=False)
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 94     64  female  31.3         2    yes  southwest  47291.06
# 328    64  female  33.8         1    yes  southwest  47928.03
# 420    64    male  33.9         0    yes  southeast  46889.26
# 664    64  female  23.0         0    yes  southeast  27037.91
# 890    64  female  26.9         0    yes  northwest  29330.98
# ...   ...     ...   ...       ...    ...        ...       ...
# 1296   18    male  26.1         0     no  northeast   1708.93
# 1315   18    male  28.3         1     no  northeast  11272.33
# 1317   18    male  53.1         0     no  southeast   1163.46
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
#
# [1338 rows x 7 columns]

# %%
raw_data.set_index('age',inplace=True)

# %%
raw_data
# Out:
#         sex   bmi  children smoker     region  expenses
# age
# 19   female  27.9         0    yes  southwest  16884.92
# 18     male  33.8         1     no  southeast   1725.55
# 28     male  33.0         3     no  southeast   4449.46
# 33     male  22.7         0     no  northwest  21984.47
# 32     male  28.9         0     no  northwest   3866.86
# ..      ...   ...       ...    ...        ...       ...
# 50     male  31.0         3     no  northwest  10600.55
# 18   female  31.9         0     no  northeast   2205.98
# 18   female  36.9         0     no  southeast   1629.83
# 21   female  25.8         0     no  southwest   2007.95
# 61   female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 6 columns]

# %%
raw_data.reset_index(inplace=True)

# %%
raw_data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Label-based locator and  Integer location-based locator

# %% [markdown]
# <pre>Key Differences:
# loc: Works with labels. Example: df.loc[0:2, 'column_name']
# iloc: Works with numerical positions. Example: df.iloc[0:2, 1:3] </pre>

# %% [markdown]
# * in order to get the rows between 2 to 9 and the columns between 2nd to 5th

# %%
raw_data.iloc[2:10,2:6]
# Out:
#     bmi  children smoker     region
# 2  33.0         3     no  southeast
# 3  22.7         0     no  northwest
# 4  28.9         0     no  northwest
# 5  25.7         0     no  southeast
# 6  33.4         1     no  southeast
# 7  27.7         3     no  northwest
# 8  29.8         2     no  northeast
# 9  25.8         0     no  northwest

# %% [markdown]
# * in order to get or skip few rows or columns while indexing
# * alternative rows we will be getting and also  columns

# %%
raw_data.iloc[2:10:2,2:6:2]
# Out:
#     bmi smoker
# 2  33.0     no
# 4  28.9     no
# 6  33.4     no
# 8  29.8     no

# %% [markdown]
# ### Group by and Aggregating

# %% [markdown]
# <pre>Common Aggregations in pandas
#
# count(): Counts non-NA entries in each group.
# sum(): Sums up the values in each group.
# mean(): Calculates the average of each group.
# median(): Calculates the median.
# min()/max(): Finds the minimum/maximum.
# std()/var(): Standard deviation and variance.
# prod(): Calculates the product of values.
# first()/last(): Returns the first/last value in each group.
# nunique(): Counts distinct values in each group</pre>

# %%
raw_data.groupby('smoker').count()
# Out:
#          age   sex   bmi  children  region  expenses
# smoker
# no      1064  1064  1064      1064    1064      1064
# yes      274   274   274       274     274       274

# %% [markdown]
# * If you want some specific columns then use that perticular columns after calling the groupby

# %%
# Gender wise Average bmi 
raw_data.groupby('sex')['bmi'].mean()
# Out:
# sex
# female    30.379758
# male      30.945266
# Name: bmi, dtype: float64

# %%
# to get the minimum age gender wise
raw_data.groupby('sex')['age'].min()
# Out:
# sex
# female    18
# male      18
# Name: age, dtype: int64

# %%
# to get the maximum age gender wise 
raw_data.groupby('sex')['age'].max()
# Out:
# sex
# female    64
# male      64
# Name: age, dtype: int64

# %% [markdown]
# * To get the gender wise region distribution

# %%
raw_data.groupby('region')['sex'].value_counts()
# Out:
# region     sex
# northeast  male      163
#            female    161
# northwest  female    164
#            male      161
# southeast  male      189
#            female    175
# southwest  male      163
#            female    162
# Name: sex, dtype: int64

# %%
raw_data.groupby('sex')['age'].value_counts()
# Out:
# sex     age
# female  18     33
#         19     33
#         47     15
#         48     15
#         51     15
#                ..
# male    60     12
#         61     11
#         62     11
#         63     11
#         64     11
# Name: age, Length: 94, dtype: int64

# %%
raw_data.groupby('region').sum().sort_values('age', ascending=False)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15336\4013134558.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   raw_data.groupby('region').sum().sort_values('age', ascending=False)
#              age      bmi  children    expenses
# region
# southeast  14174  12142.8       382  5363689.80
# southwest  12823   9943.9       371  4012754.82
# northwest  12739   9490.6       373  4035711.93
# northeast  12723   9453.1       339  4343668.64

# %% [markdown]
# * Itteration on group by

# %%
for group_name, group_data in raw_data.groupby('region'):
    print(group_name)
    print(group_data)
# Out:
# northeast
#       age     sex   bmi  children smoker     region  expenses
# 8      37    male  29.8         2     no  northeast   6406.41
# 10     25    male  26.2         0     no  northeast   2721.32
# 16     52  female  30.8         1     no  northeast  10797.34
# 17     23    male  23.8         0     no  northeast   2395.17
# 20     60  female  36.0         0     no  northeast  13228.85
# ...   ...     ...   ...       ...    ...        ...       ...
# 1321   62    male  26.7         0    yes  northeast  28101.33
# 1325   61    male  33.5         0     no  northeast  13143.34
# 1326   42  female  32.9         0     no  northeast   7050.02
# 1328   23  female  24.2         2     no  northeast  22395.74
# 1334   18  female  31.9         0     no  northeast   2205.98
#
# [324 rows x 7 columns]
# northwest
#       age     sex   bmi  children smoker     region  expenses
# 3      33    male  22.7         0     no  northwest  21984.47
# ...

# %% [markdown]
# * Multiple Agrregator function on Multiple column or single column

# %%
raw_data.groupby('region').agg({'expenses': ['sum', 'mean'], 'age': 'max'})
# Out:
#              expenses               age
#                   sum          mean max
# region
# northeast  4343668.64  13406.384691  64
# northwest  4035711.93  12417.575169  64
# southeast  5363689.80  14735.411538  64
# southwest  4012754.82  12346.937908  64

# %% [markdown]
# ### Merge and Join

# %% [markdown]
# ### Pandas Visualization

# %%
raw_data.plot(kind='bar',subplots=True)
plt.show()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# * To drop the duplicates

# %%
raw_data.drop_duplicates()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1337 rows x 7 columns]

# %%
raw_data.drop(columns=['age','sex'])
# Out:
#        bmi  children smoker     region  expenses
# 0     27.9         0    yes  southwest  16884.92
# 1     33.8         1     no  southeast   1725.55
# 2     33.0         3     no  southeast   4449.46
# 3     22.7         0     no  northwest  21984.47
# 4     28.9         0     no  northwest   3866.86
# ...    ...       ...    ...        ...       ...
# 1333  31.0         3     no  northwest  10600.55
# 1334  31.9         0     no  northeast   2205.98
# 1335  36.9         0     no  southeast   1629.83
# 1336  25.8         0     no  southwest   2007.95
# 1337  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 5 columns]

# %% [markdown]
# ### Strips
# * The strip() function in pandas is used to remove leading and trailing characters (including whitespace) from string elements in a column. This is particularly helpful for cleaning data, such as removing unwanted spaces or special characters from text data.
# * It typically apply strip() to a pandas Series or DataFrame column containing string data using the '.str' accessor.

# %% [markdown]
# #### 1. Basic Stripping
# * Removes leading and trailing whitespace (default behavior).
# * df['column'] = df['column'].str.strip()

# %%
raw_data['region'].str.strip()
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %% [markdown]
# #### 2. Stripping Specific Characters
# * Removes specified characters (e.g., $, #, or *) from both ends.

# %%
raw_data['region'].str.strip('!@#$%')
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %% [markdown]
# #### 3. Removing Only Leading Characters (lstrip)
# * Removes characters only from the beginning of the string.

# %%
raw_data['region'].str.lstrip('!@#$%')
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %% [markdown]
# #### 4. Removing Only Trailing Characters (rstrip)
# * Removes characters only from the end of the string.

# %%
raw_data['region'].str.rstrip('!@#$%')
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %% [markdown]
# #### 5. Handling Non-String Columns
# * Convert the column to string type before applying strip().

# %%
raw_data['bmi'].astype(str).str.strip()
# Out:
# 0       27.9
# 1       33.8
# 2       33.0
# 3       22.7
# 4       28.9
#         ...
# 1333    31.0
# 1334    31.9
# 1335    36.9
# 1336    25.8
# 1337    29.1
# Name: bmi, Length: 1338, dtype: object

# %% [markdown]
# #### 6. Stripping Across All Columns in a DataFrame
# * Applies strip() to all string columns in the DataFrame.

# %%
# df = df.apply(lambda col: col.str.strip() if col.dtypes == 'object' else col)

# %% [markdown]
# #### 7. Using a Regular Expression
# For advanced stripping scenarios using regex.
#
# Example: Removing all non-alphanumeric characters from the beginning and end of strings.

# %%
# df['column'] = df['column'].str.replace(r'^[^a-zA-Z0-9]+|[^a-zA-Z0-9]+$', '', regex=True)

# %% [markdown]
# # EDA

# %%
raw_data.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# * to get the sum of null values

# %%
raw_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# * to get the unique value from all the columns

# %%
raw_data.nunique()
# Out:
# age           47
# sex            2
# bmi          275
# children       6
# smoker         2
# region         4
# expenses    1337
# dtype: int64

# %% [markdown]
# * To find the correlation between the features

# %%
raw_data.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15336\2464266106.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   raw_data.corr()
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %% [markdown]
# * Asecending order

# %%
raw_data.sort_values(by='age',ascending=True)
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1248   18  female  39.8         0     no  southeast   1633.96
# 482    18  female  31.4         0     no  southeast   1622.19
# 492    18  female  25.1         0     no  northeast   2196.47
# 525    18  female  33.9         0     no  southeast  11482.63
# 529    18    male  25.5         0     no  northeast   1708.00
# ...   ...     ...   ...       ...    ...        ...       ...
# 398    64    male  25.6         2     no  southwest  14988.43
# 335    64    male  34.5         0     no  southwest  13822.80
# 378    64  female  30.1         3     no  northwest  16455.71
# 1265   64    male  23.8         0    yes  southeast  26926.51
# 635    64    male  38.2         0     no  northeast  14410.93
#
# [1338 rows x 7 columns]
